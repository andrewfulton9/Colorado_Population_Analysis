# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.plotly as ps
import numpy as np
import json

# %matplotlib inline

# %%
df = pd.read_csv('Population_Colorado.csv')

with open('colorado_counties.geojson') as f:
    counties = json.load(f)

# %%
denver_pop = df[df['county'] == 'Denver'].copy()

# %%
denver_pop_yr = denver_pop.groupby('year').sum()

denver_pop_yr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1990 to 2040
# Data columns (total 5 columns):
# fipsCode            51 non-null int64
# age                 51 non-null int64
# malePopulation      51 non-null int64
# femalePopulation    51 non-null int64
# totalPopulation     51 non-null int64
# dtypes: int64(5)
# memory usage: 2.4 KB

# %%
denver_pop_yr.plot(y = 'totalPopulation', figsize = (10,10))

# %%
denver_pop_yr.plot(y = ['malePopulation', 'femalePopulation'], figsize = (10,10))

# %%
bins = [0, 21, 34,44,54,64,90]
print bins


denver_pop['age_groups'] = pd.cut(denver_pop['age'], bins, right=False)
# Out:
# [0, 21, 34, 44, 54, 64, 90]

# %%
denver_pop.head()
# Out:
#       county  fipsCode  year  age  malePopulation  femalePopulation  \
# 925   Denver        31  1993   68            1638              2119
# 971   Denver        31  1996   36            4851              4163
# 979   Denver        31  2010    5            4116              4020
# 1028  Denver        31  1993   33            5009              4627
# 1063  Denver        31  1990   88             194               588
#
#       totalPopulation      cats age_groups
# 925              3757  [64, 90)   [64, 90)
# 971              9014  [34, 44)   [34, 44)
# 979              8136   [0, 21)    [0, 21)
# 1028             9636  [21, 34)   [21, 34)
# 1063              782  [64, 90)   [64, 90)

# %%
denver_pop_cats = denver_pop.groupby(['year', 'age_groups']).sum()
#denver_pop_cats
#denver_pop_cats.pivot(index = 'year', columns='cats', values='totalPopulation')

# %%
denver_pop_cats.unstack('age_groups')['totalPopulation'].plot()

# %%
d = {}
for x in range(len(counties['features'])):
    name = counties['features'][x]['properties']['name'][:-11]
    if name in df['county'].unique():
        d[name] = counties['features'][x]
    else:
        print 'not in: ', name

ser = pd.Series(d.values(), index = d.keys())
ser.name = 'coordinates'

# %%
scl = {0.0: 'rgb(242,240,247)',
       0.2: 'rgb(218,218,235)',
       0.4: 'rgb(188,189,220)',
       0.6: 'rgb(158,154,200)',
       0.8: 'rgb(117,107,177)',
       1.0: 'rgb(84,39,143)'}
# Out:
# {0.0: 'rgb(242,240,247)',
#  0.2: 'rgb(218,218,235)',
#  0.4: 'rgb(188,189,220)',
#  0.6: 'rgb(158,154,200)',
#  0.8: 'rgb(117,107,177)',
#  1.0: 'rgb(84,39,143)'}

# %%
full_df = full_df.groupby(['county', 'year'], as_index=False).sum()

full_df = full_df.join(ser, on='county')

# %%
full_df
# Out:
#      county  year  fipsCode   age  malePopulation  femalePopulation  \
# 0     Adams  1990        91  4095          131902            133807
# 1     Adams  1991        91  4095          136193            137427
# 2     Adams  1992        91  4095          140356            141030
# 3     Adams  1993        91  4095          145351            145431
# 4     Adams  1994        91  4095          150673            150120
# 5     Adams  1995        91  4095          156912            155675
# 6     Adams  1996        91  4095          162499            160540
# 7     Adams  1997        91  4095          167740            165010
# 8     Adams  1998        91  4095          173782            170243
# 9     Adams  1999        91  4095          179864            175445
# 10    Adams  2000        91  4095          178441            173293
# 11    Adams  2001        91  4095          182198            177236
# 12    Adams  2002        91  4095          188034            183150
# ...

# %%
max_pop = full_df['totalPopulation'].max()

# %%
def get_scl(obj):
    frac = obj / float(max_pop)
    if frac >= 0 and frac < 0.2:
        return scl[0.0]
    if frac >= 0.2 and frac < 0.4:
        return scl[0.2]
    if frac >= 0.4 and frac < 0.6:
        return scl[0.4]
    if frac >= 0.6 and frac < 0.8:
        return scl[0.6]
    if frac >= 0.8 and frac < 1:
        return scl[0.8]
    else:
        return scl[1.0]
    
full_df['color'] = full_df['totalPopulation'].apply(get_scl)

# %%
df_1990 = full_df[full_df['year'] == 2040]

# %%
df_1990.head()
# Out:
#         county  year  fipsCode   age  malePopulation  femalePopulation  \
# 50       Adams  2040        91  4095          383226            385095
# 101    Alamosa  2040       273  4095           12157             11751
# 152   Arapahoe  2040       455  4095          417629            433568
# 203  Archuleta  2040       637  4095           11227             11719
# 254       Baca  2040       819  4095            2129              2149
#
#      totalPopulation                                        coordinates  \
# 50            768312  {u'geometry': {u'type': u'MultiPolygon', u'coo...
# 101            23900  {u'geometry': {u'type': u'MultiPolygon', u'coo...
# 152           851202  {u'geometry': {u'type': u'MultiPolygon', u'coo...
# 203            22950  {u'geometry': {u'type': u'MultiPolygon', u'coo...
# 254             4277  {u'geometry': {u'type': u'MultiPolygon', u'coo...
#
#                 color
# 50   rgb(117,107,177)
# 101  rgb(242,240,247)
# 152  rgb(117,107,177)
# ...

# %%
layers_ls = []
for x in df_1990.index:
    print x
    item_dict = dict(sourcetype = 'geojson',
                     source = df_1990.ix[x]['coordinates'],
                     type = 'fill',
                     color = df_1990.ix[x]['color'])
    print item_dict
    layers_ls.append(item_dict)
# Out:
# 50
# ...

# %%
layers_ls
# Out:
# [{'color': 'rgb(117,107,177)',
#   'source': {u'geometry': {u'coordinates': [[[[-104.582488, 39.739636],
#        [-104.884646, 39.740156],
#        [-104.884664, 39.747467],
#        [-104.880138, 39.747428],
#        [-104.880228, 39.754809],
#        [-104.846932, 39.754889],
#        [-104.856431, 39.758387],
#        [-104.856377, 39.768673],
#        [-104.832961, 39.766194999999996],
#        [-104.833009, 39.769177],
#        [-104.828323, 39.769155999999995],
#        [-104.828229, 39.773174],
#        [-104.781727, 39.773387],
#        [-104.78182699999999, 39.776486],
#        [-104.772149, 39.776683999999996],
#        [-104.772166, 39.771466],
#        [-104.763225, 39.771488],
#        [-104.763126, 39.769489],
#        [-104.734601, 39.769180999999996],
#        [-104.734399, 39.798442],
#        [-104.762606, 39.798432999999996],
#        [-104.76247, 39.82298],
#        [-104.666277, 39.822849999999995],
#        [-104.666196, 39.814005],
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as graph_objs

mapbox_access_token = 'pk.eyJ1IjoiYW5kcmV3ZnVsdG9uOSIsImEiOiJjaXRnZTE1bHUwMGp1Mnlta3I3c2V0MzZiIn0.QmiVSSd9YCNn74sktO0IDg'

data = graph_objs.Data([
    graph_objs.Scattermapbox(
        lat=['45.5017'],
        lon=['-73.5673'],
        mode='markers',
    )
])
layout = graph_objs.Layout(
    height=600,
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        layers= layers_ls,
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=39.55,
            lon=-105.78
        ),
        pitch=0,
        zoom=5.2,
        style='light'
    ),
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='county-level-choropleths-python')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~andrewfulton9/0 or inside your plot.ly account where it is named 'county-level-choropleths-python'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~andrewfulton9/0.embed" height="600px" width="100%"></iframe>

# %%
import plotly.plotly as py
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] + '<br>' +\
    'Beef '+df['beef']+' Dairy '+df['dairy']+'<br>'+\
    'Fruits '+df['total fruits']+' Veggies ' + df['total veggies']+'<br>'+\
    'Wheat '+df['wheat']+' Corn '+df['corn']

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = df['total exports'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Millions USD")
        ) ]

layout = dict(
        title = '2011 US Agriculture Exports by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~andrewfulton9/2.embed" height="525px" width="100%"></iframe>

# %%
df
# Out:
#    code           state category total exports   beef    pork poultry   dairy  \
# 0    AL         Alabama    state       1390.63   34.4    10.6   481.0    4.06
# 1    AK          Alaska    state         13.31    0.2     0.1     0.0    0.19
# 2    AZ         Arizona    state       1463.17   71.3    17.9     0.0  105.48
# 3    AR        Arkansas    state       3586.02   53.2    29.4   562.9    3.53
# 4    CA      California    state      16472.88  228.7    11.1   225.4  929.95
# 5    CO        Colorado    state       1851.33  261.4    66.0    14.0   71.94
# 6    CT     Connecticut    state        259.62    1.1     0.1     6.9    9.49
# 7    DE        Delaware    state        282.19    0.4     0.6   114.7     2.3
# 8    FL         Florida    state       3764.09   42.6     0.9    56.9   66.31
# 9    GA         Georgia    state       2860.84   31.0    18.9   630.4   38.38
# 10   HI          Hawaii    state        401.84    4.0     0.7     1.3    1.16
# ...
